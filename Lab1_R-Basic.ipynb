# %% [markdown]
# # R Basic

# %% [markdown]
# ## 變數
# * R 在設定變數值時是利用「<-」並不是程式語言中常見的「=」，在 R 官方文件都強調不該使用「=」，因為在某些狀況是會失效的。另外在 R 變數命名上，大小寫是有區別的，所以 x 與 X 其實是不同的變數。

# %% [markdown]
# ### 給予變數 & 四則運算

# %%
x <- 5

# %%
y <- 8

# %%
x+y#加
# Out:
# [1] 13

# %%
x-y#減
# Out:
# [1] -3

# %%
x*y#乘
# Out:
# [1] 40

# %%
x/y#除
# Out:
# [1] 0.625

# %% [markdown]
# ### 次方、平方根

# %%
x^y#次方
# Out:
# [1] 390625

# %%
x^y==x**y
# Out:
# [1] TRUE

# %%
sqrt(x^2)#平方根
# Out:
# [1] 5

# %% [markdown]
# ### log、exp、餘數、商數、絕對值

# %%
log10(3)# log以10為底
# Out:
# [1] 0.4771213

# %%
log(3)# log以e為底
# Out:
# [1] 1.098612

# %%
exp(3)
# Out:
# [1] 20.08554

# %%
y%/%x#商數
# Out:
# [1] 1

# %%
y%%x#餘數
# Out:
# [1] 3

# %% [markdown]
# ## 向量

# %%
x<-c(1,2,3,4,5,6)
x
# Out:
# [1] 1 2 3 4 5 6

# %%
print(x)#打印
# Out:
# [1] 1 2 3 4 5 6

# %%
y<-2:7
y
# Out:
# [1] 2 3 4 5 6 7

# %%
x+y
# Out:
# [1]  3  5  7  9 11 13

# %%
x*y
# Out:
# [1]  2  6 12 20 30 42

# %%
x%*%y#內積
# Out:
#      [,1]
# [1,] 112

# %% [markdown]
# ### c(...) 類似的函數 x:y、seq 與 rep
# * seq(s, e, by)：產生一個等差級數的向量。<br/>
#  * s 是初始值 <br/>
#  * e 是結束值 <br/>
#  * by 是遞增值，預設是 1<br/>
# * rep(x, times, each)：產生一個重覆循環的向量。<br/>
#  * x 是需重覆循環的數值<br/>
#  * times 是重覆循環次數<br/>
#  * each 是 x 內元素重覆的次數

# %%
seq(5,10,2)
# Out:
# [1] 5 7 9

# %%
rep(c(1, 2, 3), times = 3, each = 2)
# Out:
#  [1] 1 1 2 2 3 3 1 1 2 2 3 3 1 1 2 2 3 3

# %% [markdown]
# ## 矩陣

# %% [markdown]
# ### 利用 matrix 建立矩陣
# * 當陣列是 2 維的狀況就是所謂的矩陣，可以利用 matix 產生矩陣，也可以用之前產生陣列的方法實作

# %%
matrix(5:8, nrow = 2, ncol = 2)
# Out:
#      [,1] [,2]
# [1,] 5    7
# [2,] 6    8

# %%
x<-matrix(5:8, nrow = 2, ncol = 2, byrow = TRUE)
x
# Out:
#      [,1] [,2]
# [1,] 5    6
# [2,] 7    8

# %%
x[1,2]
# Out:
# [1] 6

# %% [markdown]
# ##  因子

# %% [markdown]
# ###  利用 factor 建立因子
# * 因子有點像經過分級之後的向量，因子大多可以用在統計上的迴歸分析與實際設計等。

# %%
x <- c(1, 2, 4, 3, 1, 2, 3, 4,1)

# %%
factor(x)
# Out:
# [1] 1 2 4 3 1 2 3 4 1
# Levels: 1 2 3 4

# %%
factor(x, ordered = TRUE)
# Out:
# [1] 1 2 4 3 1 2 3 4 1
# Levels: 1 < 2 < 3 < 4

# %% [markdown]
# ## 資料框架

# %% [markdown]
# ### 利用 data.frame 建立資料框架
# * 資料框架類似資料表，常當作大量資料集，例如：匯入外部檔或讀取資料庫資料等。

# %%
name <- c("Joe", "Bob", "Vicky")

# %%
age <- c("28", "26", "34")

# %%
gender <- c("Male","Male","Female")

# %%
data <- data.frame(name, age, gender)

# %%
data
# Out:
#   name  age gender
# 1 Joe   28  Male
# 2 Bob   26  Male
# 3 Vicky 34  Female

# %%
data[1,]
# Out:
#   name age gender
# 1 Joe  28  Male

# %%
data[,3]
# Out:
# [1] Male   Male   Female
# Levels: Female Male

# %%
summary(data)
# Out:
#     name   age       gender
#  Bob  :1   26:1   Female:1
#  Joe  :1   28:1   Male  :2
#  Vicky:1   34:1

# %%
str(data)
# Out:
# 'data.frame':	3 obs. of  3 variables:
#  $ name  : Factor w/ 3 levels "Bob","Joe","Vicky": 2 1 3
#  $ age   : Factor w/ 3 levels "26","28","34": 2 1 3
#  $ gender: Factor w/ 2 levels "Female","Male": 2 2 1

# %%
colnames(data)
# Out:
# [1] "name"   "age"    "gender"

# %% [markdown]
# ### iris data

# %%
iris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
plot(iris)
# Out:
# plot without title

# %%
plot(iris$Sepal.Length,iris$Sepal.Width)
# Out:
# plot without title

# %% [markdown]
# ## 邏輯判斷式

# %% [markdown]
# ### 大於、小於、等於、不等於、交集、聯集

# %%
x<-5
y<-10

# %%
x>y
# Out:
# [1] FALSE

# %%
x<=y
# Out:
# [1] TRUE

# %%
x!=y#不等於
# Out:
# [1] TRUE

# %%
a<-c(1,2,3,4,5)
a>0 & a>6 #交集
a>0 | a>6 #交集
# Out:
# [1] FALSE FALSE FALSE FALSE FALSE
# [1] TRUE TRUE TRUE TRUE TRUE

# %% [markdown]
# ## 條件執行

# %% [markdown]
# *  if else

# %%
x <- 1
if (x > 0) {
   y <- 5
 } else {
   y <- 10
 }
y
# Out:
# [1] 5

# %%
x <- -5
if (x > 0) {
   y <- 5
 } else {
   y <- 10
 }
y
# Out:
# [1] 10

# %%
x<- 6 
y <- ifelse(x > 0, 5, 10)
y
# Out:
# [1] 5

# %% [markdown]
# ## 迴圈

# %% [markdown]
# * for

# %%
y <- 0
for (x in c(1:10)) 
    y <- x + y 
y
# Out:
# [1] 55

# %% [markdown]
# * while

# %%
x <- 1
y <- 0
while (x <= 10) { # while 只要符合判斷式，就會一直重複執行括號內程式碼，直到不符合為止。
   y <- x + y
  x <- x + 1 # 這行很重要，如果沒有這行，程式碼會一直執行不會停止，因為判斷式是 x 小於等於 10，x 初始值是 0，如果不對 x 做些動作，x 會一直小於等於 10，所以這邊加 1，是希望執行到 x = 11 時，迴圈就會停止。
 }
y
# Out:
# [1] 55

# %% [markdown]
# ## Help

# %%
?matrix

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. 使用 length (x) ，如果 x 是 向量 [1,2,3]

# %%
x <- c(1,2,3)
length(x)
# Out:
# [1] 3

# %% [markdown]
# ### 2. 使用 mean(x)、sd(x) ，如果 x是隨機產生50個數字來自於常態分佈

# %%
x<-rnorm(50)

# %%
x
# Out:
#  [1] -0.23727107  1.74536570  0.35916347  1.43630077  1.26304815 -1.44615687
#  [7] -0.02960330 -0.21433045  0.74144188  1.14250663  0.41567476 -0.31564861
# [13] -0.72766691 -1.62053084  1.06556459  0.41513363 -1.12528700  1.09289206
# [19]  0.57026277  0.48381960 -0.95038337  0.68773405 -1.37536847 -1.17743155
# [25]  0.40591043  0.58913870 -0.09374697 -0.80541117 -0.69592780 -3.80944812
# [31]  0.40983919 -0.07174227  2.01568337  1.47931242  0.95751447 -1.06962140
# [37] -2.37218029  0.01582889 -0.67254565 -0.42480272 -0.30501862  1.65722506
# [43] -0.86754275  0.75988864 -2.23804202  0.92123130 -0.22684719 -1.21856022
# [49] -0.20039380 -0.51562235

# %%
mean(x)
sd(x)
# Out:
# [1] -0.08353302
# [1] 1.158154

# %% [markdown]
# ### 3. 產生 x、y、z皆是隨機產生50個數字來自於常態分佈，並合併為一個資料框架

# %%
set.seed(123)
x<-rnorm(50)
y<-rnorm(50)
z<-rnorm(50)
data_xyz<-data.frame(x,y,z)

# %%
head(data_xyz)
# Out:
#   x           y           z
# 1 -0.56047565  0.25331851 -0.71040656
# 2 -0.23017749 -0.02854676  0.25688371
# 3  1.55870831 -0.04287046 -0.24669188
# 4  0.07050839  1.36860228 -0.34754260
# 5  0.12928774 -0.22577099 -0.95161857
# 6  1.71506499  1.51647060 -0.04502772

# %% [markdown]
# ### 4. 安裝 "ISLR" package，並讀取裡面的資料Auto，使用 summary()，pairs()觀察資料的變化

# %%
install.packages("ISLR")
# Out:
# Installing package into 'C:/Users/stu95/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'ISLR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\stu95\AppData\Local\Temp\Rtmp2zY1xM\downloaded_packages

# %%
library("ISLR")

# %%
head(Auto)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1 18  8         307          130        3504   12.0         70   1
# 2 15  8         350          165        3693   11.5         70   1
# 3 18  8         318          150        3436   11.0         70   1
# 4 16  8         304          150        3433   12.0         70   1
# 5 17  8         302          140        3449   10.5         70   1
# 6 15  8         429          198        4341   10.0         70   1
#   name
# 1 chevrolet chevelle malibu
# 2 buick skylark 320
# 3 plymouth satellite
# 4 amc rebel sst
# 5 ford torino
# 6 ford galaxie 500

# %%
summary(Auto)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#
#   acceleration        year           origin                      name
#  Min.   : 8.00   Min.   :70.00   Min.   :1.000   amc matador       :  5
#  1st Qu.:13.78   1st Qu.:73.00   1st Qu.:1.000   ford pinto        :  5
#  Median :15.50   Median :76.00   Median :1.000   toyota corolla    :  5
#  Mean   :15.54   Mean   :75.98   Mean   :1.577   amc gremlin       :  4
# ...

# %%
pairs(Auto)
# Out:
# plot without title

# %% [markdown]
# ### 5.  為了建構「樹」的識別系統，一家公司決定在網路上收集一百萬張圖片。
# ###      然後，公司要求10名員工，每人查看100張圖片並標註每張圖片是否包含樹。
# ###      再把圖片和標註的紀錄送到「學習算法」以構建系統。 該算法需要解決哪種學習問題？
#  1. 監督式學習(Supervised Learning)
#  2. 非監督式學習(Unsupervised Learning)
#  3. 半監督式學習(Semi-supervised Learning )
#  4. 強化學習(Reinforcement Learning)

# %% [markdown]
# ### Ans:(3)，因為有1000張照片是有被標註的，而另外的999000張照片是沒有被標註的，所以有包含標註即沒有標註的資料適用於半監督式學習。
